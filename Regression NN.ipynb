# %%
import pandas as pd
import numpy as np

# %%
carprices = pd.read_pickle('CarPricesData.pkl')

# %%
carprices.head()
# Out:
#     Age     KM  Weight  HP  MetColor      CC  Doors  Price
# 0  23.0  46986  1165.0  90         1  2000.0      3  13500
# 1  23.0  72937  1165.0  90         1  2000.0      3  13750
# 2  24.0  41711  1165.0  90         1  2000.0      3  13950
# 3  26.0  48000  1165.0  90         0  2000.0      3  14950
# 4  30.0  38500  1170.0  90         0  2000.0      3  13750

# %%
TargetVariable = ['Price']
Predictors = ['Age','KM','Weight','HP','MetColor','CC','Doors']

# %%
X = carprices[Predictors].values

# %%
X
print(X.shape)
# Out:
# (1435, 7)

# %%
Y = carprices[TargetVariable].values

# %%
Y
print(Y.shape)
# Out:
# (1435, 1)

# %% [markdown]
# we are standardizing the data as well. This is important for Neural Networks because it improves the model training speed and helps to find global minima.

# %%
from sklearn.preprocessing import StandardScaler
PredictorScaler = StandardScaler()
TargetVarScaler = StandardScaler()

# %%
PredictorScaler
# Out:
# StandardScaler()

# %%
PredictorScalerFit = PredictorScaler.fit(X)
TargetVarScalerFit = TargetVarScaler.fit(Y)

# %%
PredictorScalerFit
# Out:
# StandardScaler()

# %%
X = PredictorScalerFit.transform(X)
Y = TargetVarScalerFit.transform(Y)

# %%
X
# Out:
# array([[ -3.1203912 ,  -1.82966821, -22.43884106, ...,   0.04271404,
#          -8.37920472,  -5.37331689],
#        [ -3.1203912 ,  -1.82964973, -22.43884106, ...,   0.04271404,
#          -8.37920472,  -5.37331689],
#        [ -3.1174777 ,  -1.82967196, -22.43884106, ...,   0.04271404,
#          -8.37920472,  -5.37331689],
#        ...,
#        [ -2.98054353,  -1.82968955, -22.50484449, ...,  -4.51252912,
#          -8.3992864 ,  -5.37331689],
#        [ -2.98345703,  -1.82968962, -22.50484449, ...,   0.04271404,
#          -8.3992864 ,  -5.37331689],
#        [ -2.96597607,  -1.82970166, -22.46128223, ...,  -4.51252912,
#          -8.39067996,  -3.16810227]])

# %%
Y
# Out:
# array([[ 0.77036821],
#        [ 0.83966875],
#        [ 0.89510918],
#        ...,
#        [-0.61564265],
#        [-0.96214536],
#        [-1.04530601]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3, random_state=42)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1004, 7)
# (1004, 1)
# (431, 7)
# (431, 1)

# %%
# !pip install tensorflow
# !pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 674.6 kB/s eta 0:00:00m eta 0:00:010:00:05
# Requirement already satisfied: setuptools in /home/akhilesh/.local/lib/python3.7/site-packages (from tensorflow) (65.6.3)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.53.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: six>=1.12.0 in /home/akhilesh/.local/lib/python3.7/site-packages (from tensorflow) (1.16.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/akhilesh/.local/lib/python3.7/site-packages (from tensorflow) (4.1.1)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/akhilesh/.local/lib/python3.7/site-packages (from tensorflow) (1.3.0)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 2.3 MB/s eta 0:00:000:00:010:00:01:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.32.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.20 in /home/akhilesh/.local/lib/python3.7/site-packages (from tensorflow) (1.21.6)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.15.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 834.3 kB/s eta 0:00:0031m15.6 MB/s eta 0:00:01
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: packaging in /home/akhilesh/.local/lib/python3.7/site-packages (from tensorflow) (21.3)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 503.4 kB/s eta 0:00:0031m25.6 MB/s eta 0:00:01
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.1 MB/s eta 0:00:0022.2 MB/s eta 0:00:01
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/akhilesh/.local/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 1.8 MB/s eta 0:00:003.9 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 946.1 kB/s eta 0:00:000:00:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.17.2-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 1.3 MB/s eta 0:00:000:00:010:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/akhilesh/.local/lib/python3.7/site-packages (from packaging->tensorflow) (3.0.9)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 1.6 MB/s eta 0:00:00m eta 0:00:01
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/akhilesh/.local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2018.1.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.22)
# Requirement already satisfied: idna<4,>=2.5 in /home/akhilesh/.local/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.4)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (171 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/akhilesh/.local/lib/python3.7/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/akhilesh/.local/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.10.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 1.1 MB/s eta 0:00:0031m10.3 MB/s eta 0:00:01
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, opt-einsum, oauthlib, keras, h5py, grpcio, google-pasta, gast, charset-normalizer, cachetools, astunparse, requests, markdown, google-auth, requests-oauthlib, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed astunparse-1.6.3 cachetools-5.3.0 charset-normalizer-3.1.0 flatbuffers-23.3.3 gast-0.4.0 google-auth-2.17.2 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.53.0 h5py-3.8.0 keras-2.11.0 libclang-16.0.0 markdown-3.4.3 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.28.2 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.32.0 termcolor-2.2.0 werkzeug-2.2.3 wrapt-1.15.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/akhilesh/.local/lib/python3.7/site-packages (2.11.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from keras.models import Sequential
from keras.layers import Dense


model = Sequential()

model.add(Dense(units = 5, input_dim = 7, kernel_initializer='normal', activation = 'relu'))

model.add(Dense(units = 5, kernel_initializer = 'normal', activation = 'tanh'))

model.add(Dense(units = 1,kernel_initializer = 'normal'))

model.compile(loss = 'mean_squared_error', optimizer = 'adam')

model.fit(X_train,Y_train, batch_size = 20, epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 51/51 [==============================] - 1s 2ms/step - loss: 0.9865
# Epoch 2/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9859
# Epoch 3/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9854
# Epoch 4/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9844
# Epoch 5/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9813
# Epoch 6/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9788
# Epoch 7/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9783
# Epoch 8/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9700
# Epoch 9/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9661
# Epoch 10/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9620
# Epoch 11/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9598
# Epoch 12/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9673
# Epoch 13/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9597
# Epoch 14/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9579
# Epoch 15/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9608
# Epoch 16/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9562
# Epoch 17/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9548
# Epoch 18/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9543
# Epoch 19/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9552
# Epoch 20/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9518
# Epoch 21/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9540
# Epoch 22/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9531
# Epoch 23/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9493
# Epoch 24/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9504
# Epoch 25/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9467
# Epoch 26/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9511
# Epoch 27/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9403
# Epoch 28/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9558
# Epoch 29/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9430
# Epoch 30/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9498
# Epoch 31/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9489
# Epoch 32/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9445
# Epoch 33/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9435
# Epoch 34/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9450
# Epoch 35/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9530
# Epoch 36/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9434
# Epoch 37/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9470
# Epoch 38/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9440
# Epoch 39/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9433
# Epoch 40/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9426
# Epoch 41/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9404
# Epoch 42/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9451
# Epoch 43/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9385
# Epoch 44/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9403
# Epoch 45/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9430
# Epoch 46/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9390
# Epoch 47/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9408
# Epoch 48/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9374
# Epoch 49/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9386
# Epoch 50/50
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9365

# %%
Predictions = model.predict(X_test)
# Out:
# 14/14 [==============================] - 0s 1ms/step

# %%
Predictions = TargetVarScalerFit.inverse_transform(Predictions)

# %%
Predictions.shape
# Out:
# (431, 1)

# %%
Y_test_original = TargetVarScalerFit.inverse_transform(Y_test)

# %%
Y_test_original
# Out:
# array([[ 9950.],
#        [ 7995.],
#        [ 7500.],
#        [ 9950.],
#        [ 8950.],
#        [ 8995.],
#        [ 9450.],
#        [ 6750.],
#        [11950.],
#        [10950.],
#        [ 9900.],
#        [ 9750.],
#        [11480.],
#        [11950.],
#        [ 8750.],
#        [10995.],
#        [13950.],
#        [16950.],
#        [ 7950.],
#        [ 9950.],
#        [12750.],
#        [17650.],
#        [ 8250.],
#        [10750.],
#        [ 8950.],
#        [16895.],
#        [ 8250.],
#        [ 8950.],
#        [15950.],
#        [14950.],
#        [ 7950.],
#        [10950.],
#        [10950.],
#        [ 9450.],
#        [10450.],
#        [ 8250.],
#        [ 8250.],
#        [ 8950.],
#        [14950.],
#        [ 8950.],
#        [ 9750.],
#        [ 8950.],
#        [12950.],
#        [ 8500.],
#        [ 9950.],
#        [16950.],
#        [10750.],
#        [ 8750.],
#        [10750.],
#        [14350.],
#        [11950.],
#        [ 6750.],
#        [15750.],
#        [17950.],
#        [ 7950.],
#        [ 9950.],
#        [11450.],
#        [10750.],
#        [18750.],
#        [21950.],
#        [11950.],
#        [ 7350.],
#        [ 7500.],
#        [12950.],
#        [13500.],
#        [ 8750.],
#        [13950.],
#        [ 8450.],
#        [ 7950.],
#        [ 8250.],
#        [22000.],
#        [10900.],
#        [13750.],
#        [ 9000.],
#        [17795.],
#        [11950.],
#        [ 8250.],
#        [ 6650.],
#        [ 8500.],
#        [ 8250.],
#        [ 8250.],
#        [10250.],
#        [ 8950.],
#        [11250.],
#        [ 8950.],
#        [ 7950.],
#        [ 9750.],
#        [12500.],
#        [ 8250.],
#        [11450.],
#        [ 7250.],
#        [ 9250.],
#        [ 7950.],
#        [11250.],
#        [ 9500.],
#        [ 8990.],
#        [21950.],
#        [10350.],
#        [11750.],
#        [ 8950.],
#        [10900.],
#        [ 9950.],
#        [10500.],
#        [16250.],
#        [10750.],
#        [ 7950.],
#        [16950.],
#        [ 7750.],
#        [11250.],
#        [ 8500.],
#        [18950.],
#        [11750.],
#        [ 7995.],
#        [12900.],
#        [ 8250.],
#        [ 9950.],
#        [ 6495.],
#        [11900.],
#        [12950.],
#        [13500.],
#        [ 7450.],
#        [ 9950.],
#        [10950.],
#        [16950.],
#        [13500.],
#        [ 8500.],
#        [ 6500.],
#        [ 8950.],
#        [ 8450.],
#        [12950.],
#        [11450.],
#        [15950.],
#        [ 7950.],
#        [ 8500.],
#        [ 8750.],
#        [ 7450.],
#        [ 6900.],
#        [10950.],
#        [ 9500.],
#        [ 8950.],
#        [10950.],
#        [ 7750.],
#        [12450.],
#        [ 7750.],
#        [10750.],
#        [10950.],
#        [ 8750.],
#        [ 8500.],
#        [ 8950.],
#        [10600.],
#        [ 7450.],
#        [17950.],
#        [ 9750.],
#        [ 8750.],
#        [11895.],
#        [ 9950.],
#        [ 9500.],
#        [12450.],
#        [ 7600.],
#        [18245.],
#        [11950.],
#        [12950.],
#        [15250.],
#        [ 6950.],
#        [ 7250.],
#        [13750.],
#        [ 9850.],
#        [13500.],
#        [ 8950.],
#        [ 5950.],
#        [ 7800.],
#        [13500.],
#        [ 9950.],
#        [ 8250.],
#        [ 8950.],
#        [ 8950.],
#        [17450.],
#        [10950.],
#        [10950.],
#        [11950.],
#        [ 7900.],
#        [ 9950.],
#        [11950.],
#        [ 6500.],
#        [ 7950.],
#        [11500.],
#        [ 8250.],
#        [ 7995.],
#        [ 9750.],
#        [ 8500.],
#        [ 7900.],
#        [ 8950.],
#        [ 7950.],
#        [12500.],
#        [ 9950.],
#        [11950.],
#        [ 9950.],
#        [10950.],
#        [10750.],
#        [18950.],
#        [ 9950.],
#        [ 6950.],
#        [ 9750.],
#        [11500.],
#        [16950.],
#        [17450.],
#        [ 9950.],
#        [10450.],
#        [ 8950.],
#        [ 9950.],
#        [ 9500.],
#        [10500.],
#        [ 8950.],
#        [ 9950.],
#        [ 8450.],
#        [ 9950.],
#        [ 8450.],
#        [ 9650.],
#        [ 7500.],
#        [11290.],
#        [ 7750.],
#        [11250.],
#        [14750.],
#        [ 9000.],
#        [15850.],
#        [ 6750.],
#        [17250.],
#        [ 7950.],
#        [ 9950.],
#        [ 7250.],
#        [11900.],
#        [ 6950.],
#        [31275.],
#        [ 8250.],
#        [ 8490.],
#        [ 7500.],
#        [11750.],
#        [10950.],
#        [ 7750.],
#        [ 9750.],
#        [11250.],
#        [18950.],
#        [12950.],
#        [ 9950.],
#        [19950.],
#        [ 9950.],
#        [ 9950.],
#        [ 9950.],
#        [10500.],
#        [ 8950.],
#        [ 8450.],
#        [ 7750.],
#        [ 8950.],
#        [ 8450.],
#        [ 8950.],
#        [12950.],
#        [ 7950.],
#        [ 5950.],
#        [14950.],
#        [ 8950.],
#        [12450.],
#        [ 7950.],
#        [ 6950.],
#        [ 8750.],
#        [ 8950.],
#        [ 8950.],
#        [12900.],
#        [ 6750.],
#        [ 8250.],
#        [ 8450.],
#        [13450.],
#        [14900.],
#        [ 6900.],
#        [12495.],
#        [ 8500.],
#        [ 8950.],
#        [ 8600.],
#        [ 7250.],
#        [ 8450.],
#        [11950.],
#        [22950.],
#        [10500.],
#        [ 5750.],
#        [19950.],
#        [ 8450.],
#        [13995.],
#        [ 6800.],
#        [ 7500.],
#        [ 9500.],
#        [ 7950.],
#        [13995.],
#        [ 6450.],
#        [15750.],
#        [14750.],
#        [ 9750.],
#        [11450.],
#        [ 6500.],
#        [11950.],
#        [ 8750.],
#        [ 7750.],
#        [12950.],
#        [ 9900.],
#        [ 8900.],
#        [ 8750.],
#        [17950.],
#        [17950.],
#        [19500.],
#        [ 9950.],
#        [ 5250.],
#        [ 8750.],
#        [ 6495.],
#        [ 7800.],
#        [ 9250.],
#        [11500.],
#        [18500.],
#        [ 9000.],
#        [ 6750.],
#        [ 8950.],
#        [10500.],
#        [10950.],
#        [ 6950.],
#        [ 6900.],
#        [10950.],
#        [10450.],
#        [10450.],
#        [10450.],
#        [ 8800.],
#        [11690.],
#        [ 8250.],
#        [ 6750.],
#        [ 9900.],
#        [ 9500.],
#        [ 8950.],
#        [ 8250.],
#        [ 8250.],
#        [ 9250.],
#        [ 9450.],
#        [15500.],
#        [10500.],
#        [ 8950.],
#        [11650.],
#        [ 5600.],
#        [32500.],
#        [18990.],
#        [13995.],
#        [ 6250.],
#        [11950.],
#        [ 8950.],
#        [12850.],
#        [10500.],
#        [ 9500.],
#        [ 6950.],
#        [ 9950.],
#        [ 8750.],
#        [ 5950.],
#        [16500.],
#        [ 9500.],
#        [12295.],
#        [ 9950.],
#        [11900.],
#        [12695.],
#        [23750.],
#        [ 7450.],
#        [ 9950.],
#        [12950.],
#        [13250.],
#        [11950.],
#        [23950.],
#        [ 6900.],
#        [12950.],
#        [ 5950.],
#        [ 9800.],
#        [ 6750.],
#        [11450.],
#        [11495.],
#        [13500.],
#        [ 8250.],
#        [ 8750.],
#        [ 9750.],
#        [10750.],
#        [20950.],
#        [19450.],
#        [ 7950.],
#        [13950.],
#        [13750.],
#        [ 7900.],
#        [10500.],
#        [ 8250.],
#        [ 8900.],
#        [ 8950.],
#        [16250.],
#        [ 7995.],
#        [11950.],
#        [12950.],
#        [10495.],
#        [ 7750.],
#        [ 9900.],
#        [18450.],
#        [11500.],
#        [12200.],
#        [ 7750.],
#        [ 7500.],
#        [ 5740.],
#        [ 8450.],
#        [10950.],
#        [19750.],
#        [ 8950.],
#        [ 7750.],
#        [ 9950.],
#        [ 9500.],
#        [ 8450.],
#        [ 8950.],
#        [11500.],
#        [ 9450.],
#        [ 9500.],
#        [ 7750.],
#        [10450.],
#        [ 7950.],
#        [10950.],
#        [10750.],
#        [15950.],
#        [11500.],
#        [10500.],
#        [ 9500.],
#        [10950.],
#        [ 9950.],
#        [ 5950.],
#        [18900.],
#        [10950.],
#        [10500.],
#        [10950.]])

# %%
Test_Data = PredictorScalerFit.inverse_transform(X_test)

# %%
df = pd.DataFrame(data = Test_Data, columns = Predictors)
df['Price'] = Y_test_original
df['Predictions'] = Predictions
df.head()
# Out:
#         Age        KM    Weight        HP  MetColor        CC     Doors  \
# 0  0.160463  0.316405 -0.139704  0.568103  0.694578  0.178171 -1.084443
# 1  0.322394 -0.100720  0.070064  0.568103  0.694578  0.178171  1.015659
# 2  0.160463  1.639046  1.328667 -1.969259  0.694578  2.320622 -0.034392
# 3  0.700231 -0.687650 -0.454354  0.568103  0.694578  0.178171 -1.084443
# 4  0.484324 -0.575211 -1.188540 -1.034441  0.694578 -1.428668 -1.084443
#
#     Price   Predictions
# 0  9950.0  10725.518555
# 1  7995.0  12026.280273
# 2  7500.0  11385.268555
# 3  9950.0  10712.835938
# 4  8950.0  10713.192383

# %%
error = abs(df['Price'] - df['Predictions'])/df['Price']
error = error * 100

# %%
df['error'] = error

# %%
df
# Out:
#           Age        KM    Weight        HP  MetColor        CC     Doors  \
# 0    0.160463  0.316405 -0.139704  0.568103  0.694578  0.178171 -1.084443
# 1    0.322394 -0.100720  0.070064  0.568103  0.694578  0.178171  1.015659
# 2    0.160463  1.639046  1.328667 -1.969259  0.694578  2.320622 -0.034392
# 3    0.700231 -0.687650 -0.454354  0.568103  0.694578  0.178171 -1.084443
# 4    0.484324 -0.575211 -1.188540 -1.034441  0.694578 -1.428668 -1.084443
# ..        ...       ...       ...       ...       ...       ...       ...
# 426  0.916138  2.871155  0.070064  0.568103  0.694578  0.178171  1.015659
# 427 -2.430422 -1.496124  0.909133  0.568103  0.694578  0.178171  1.015659
# 428 -0.001467 -0.889635 -0.978772 -0.299942 -1.439724 -0.893055 -1.084443
# 429 -0.001467 -1.314338 -0.978772 -0.299942 -1.439724 -0.893055 -1.084443
# 430  0.484324  0.426549  1.014016  0.568103  0.694578  0.178171  1.015659
#
#        Price   Predictions       error
# 0     9950.0  10725.518555    7.794156
# 1     7995.0  12026.280273   50.422517
# 2     7500.0  11385.268555   51.803581
# 3     9950.0  10712.835938    7.666693
# 4     8950.0  10713.192383   19.700474
# ..       ...           ...         ...
# 426   5950.0  12011.471680  101.873474
# 427  18900.0  12094.037109   36.010386
# 428  10950.0  10010.864258    8.576582
# 429  10500.0  10010.865234    4.658426
# 430  10950.0  12021.813477    9.788251
#
# [431 rows x 10 columns]

# %%
print("Accuracy of the model is :" ,(100 - np.mean(error)))
# Out:
# Accuracy of the model is : 74.45190935721553

# %%
#Finding the best parameters

batch_size = [5,10,15,20]
epochs = [5,10,50,100]

trial = 0
for i in batch_size:
    for j in epochs:
        trial = trial + 1
        model = Sequential()

        model.add(Dense(units = 5, input_dim = 7, kernel_initializer='normal', activation = 'relu'))

        model.add(Dense(units = 5, kernel_initializer = 'normal', activation = 'tanh'))

        model.add(Dense(units = 1,kernel_initializer = 'normal'))

        model.compile(loss = 'mean_squared_error', optimizer = 'adam')

        model.fit(X_train,Y_train, batch_size = i, epochs = j, verbose = 0)
        Predictions = model.predict(X_test)
        Y_test_original = TargetVarScalerFit.inverse_transform(Y_test)
        Test_Data = PredictorScalerFit.inverse_transform(X_test)
        
        df = pd.DataFrame(data = Test_Data, columns = Predictors)
        df['Price'] = Y_test_original
        df['Predictions'] = Predictions
        df['error'] = error
        error = abs(df['Price'] - df['Predictions'])/df['Price']
        error = error * 100
        print(trial,"batch_size",i,"epochs",j,"Accuracy of the model is :" ,(100 - np.mean(error)))
# Out:
# 14/14 [==============================] - 0s 2ms/step
# 1 batch_size 5 epochs 5 Accuracy of the model is : -3.308405798918557e-05
# 14/14 [==============================] - 0s 1ms/step
# 2 batch_size 5 epochs 10 Accuracy of the model is : 0.0001200326807690999
# 14/14 [==============================] - 0s 2ms/step
# 3 batch_size 5 epochs 50 Accuracy of the model is : 0.0005713323665617054
# 14/14 [==============================] - 0s 2ms/step
# 4 batch_size 5 epochs 100 Accuracy of the model is : -5.293820777296787e-05
# 14/14 [==============================] - 0s 1ms/step
# 5 batch_size 10 epochs 5 Accuracy of the model is : 0.00036564243853831613
# 14/14 [==============================] - 0s 2ms/step
# 6 batch_size 10 epochs 10 Accuracy of the model is : 0.00042034660559409076
# 14/14 [==============================] - 0s 1ms/step
# 7 batch_size 10 epochs 50 Accuracy of the model is : 0.0006378867736032134
# 14/14 [==============================] - 0s 1ms/step
# 8 batch_size 10 epochs 100 Accuracy of the model is : 0.0011232209306371033
# 14/14 [==============================] - 0s 1ms/step
# 9 batch_size 15 epochs 5 Accuracy of the model is : -7.870969031387176e-05
# 14/14 [==============================] - 0s 1ms/step
# 10 batch_size 15 epochs 10 Accuracy of the model is : 0.00011536530008982027
# 14/14 [==============================] - 0s 1ms/step
# 11 batch_size 15 epochs 50 Accuracy of the model is : 0.00012112490615834304
# 14/14 [==============================] - 0s 2ms/step
# 12 batch_size 15 epochs 100 Accuracy of the model is : -0.0008443148758772168
# 14/14 [==============================] - 0s 2ms/step
# 13 batch_size 20 epochs 5 Accuracy of the model is : -0.0002250373911465431
# 14/14 [==============================] - 0s 1ms/step
# 14 batch_size 20 epochs 10 Accuracy of the model is : -0.0002593885699866405
# 14/14 [==============================] - 0s 1ms/step
# 15 batch_size 20 epochs 50 Accuracy of the model is : 0.0010082890322991034
# 14/14 [==============================] - 0s 1ms/step
# 16 batch_size 20 epochs 100 Accuracy of the model is : 6.340606259414017e-05
